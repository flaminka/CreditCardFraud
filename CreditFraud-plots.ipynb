# %%
import pandas as pd
#import numpy as np
#sciezka = "C:/Users/USER/Desktop"
#dane = pd.read_csv(sciezka+"creditcard.cs")
#dane=np.genfromtxt("C:/Users/USER/Desktop/vcreditcard.csv", unpack=True, skiprows = 1)
dane = pd.read_csv("C:/Users/USER/Desktop/creditcard.csv",encoding='latin1')

dane.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import dateutil
su=sum(dane['Class']==1)
print ("In our data we have %d frouds." %su)

classes = pd.value_counts(dane['Class'], sort = True).sort_index()
classes.plot(kind = 'bar')
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.show()
# Out:
# In our data we have 492 frouds.

# %%
print ("The plot show how many frouds were in time." )

f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10,10))


ax1.hist(dane.Time[dane.Class == 1], color='red')
ax1.set_title('Fraud')


ax2.hist(dane.Time[dane.Class == 0], color='green')
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Number of Transactions')
plt.show()
# Out:
# The plot show how many frouds were in time.

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10,6))

ax1.scatter(dane.Time[dane.Class == 1], dane.Amount[dane.Class == 1], color='red')
ax1.set_title('Fraud')

ax2.scatter(dane.Time[dane.Class == 0], dane.Amount[dane.Class == 0], color='green')
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
#import plotly.plotly as py
#import plotly.graph_objs as go

#import numpy as np

#x0 = dane.Amount[dane.Class == 0]
#x1 =dane.Amount[dane.Class == 1]

#trace0 = go.Box(x=x0)
#trace1 = go.Box(x=x1)
#data = [trace0, trace1]
#py.iplot(data)

# %%
#from matplotlib import pyplot as plt
n0=plt.scatter(dane.Time[dane.Class == 0], dane.Amount[dane.Class == 0],color='green', label='Normal')
n1=plt.scatter(dane.Time[dane.Class == 1], dane.Amount[dane.Class == 1],color='red', label='Froud')
# Add a legend at the lower center
plt.legend((n0, n1),('Normal', 'Froud'),scatterpoints=1, loc='upper left', ncol=1, fontsize=8)

# Add axis labels and title
plt.xlabel('Time')
plt.ylabel('Amount')
plt.title('Amount vs time')
plt.rcParams['font.size']=10
plt.show()

# %%
#from matplotlib import pyplot as plt
n0=plt.scatter(dane.V1[dane.Class == 0],dane.V1[dane.Class == 0],color='green', label='Normal')
n1=plt.scatter(dane.V1[dane.Class == 1],dane.V1[dane.Class == 1],color='red', label='Froud')
# Add a legend at the lower center
plt.legend((n0, n1),('Normal', 'Froud'),scatterpoints=1, loc='upper left', ncol=1, fontsize=8)

# Add axis labels and title
plt.xlabel('V1')
plt.ylabel('V1')
plt.title('V1')
plt.rcParams['font.size']=10
plt.show()

# %%
n0=plt.scatter(dane.V3[dane.Class == 0],dane.V3[dane.Class == 0],color='green', label='Normal')
n1=plt.scatter(dane.V3[dane.Class == 1],dane.V3[dane.Class == 1],color='red', label='Froud')
# Add a legend at the lower center
plt.legend((n0, n1),('Normal', 'Froud'),scatterpoints=1, loc='upper left', ncol=1, fontsize=8)

# Add axis labels and title
plt.xlabel('V1')
plt.ylabel('V1')
plt.title('V1')
plt.rcParams['font.size']=10
plt.show()

# %%
from matplotlib import pyplot
import numpy
bins = numpy.linspace(-10, 10, 100)

pyplot.hist(dane.V3[dane.Class == 0], bins, alpha=0.5, label='Normal',color='green')
pyplot.hist(dane.V3[dane.Class == 1], bins, alpha=0.5, label='Froud',color='red')
pyplot.legend(loc='upper left')
pyplot.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(10,10))


ax1.hist(dane.V3[dane.Class == 1], color='red')
ax1.set_title('Fraud')


ax2.hist(dane.V3[dane.Class == 0], color='green')
ax2.set_title('Normal')

plt.xlabel('V3')
#plt.ylabel('Number of Transactions')
plt.show()

#wykres średniej kwoty w czasie w podziale na normal i fraud + to samo z medianą
